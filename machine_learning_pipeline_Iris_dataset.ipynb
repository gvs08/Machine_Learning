# %%
import pandas as pd
df=pd.read_csv('Iris.csv')

# %%
df.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 118  119            7.7           2.6            6.9           2.3
# 47    48            4.6           3.2            1.4           0.2
# 72    73            6.3           2.5            4.9           1.5
# 120  121            6.9           3.2            5.7           2.3
#
#              Species
# 100   Iris-virginica
# 118   Iris-virginica
# 47       Iris-setosa
# 72   Iris-versicolor
# 120   Iris-virginica

# %%
df.drop('Id',axis=1,inplace=True)

# %%
df.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 130            7.4           2.8            6.1           1.9   Iris-virginica
# 72             6.3           2.5            4.9           1.5  Iris-versicolor
# 18             5.7           3.8            1.7           0.3      Iris-setosa
# 142            5.8           2.7            5.1           1.9   Iris-virginica
# 57             4.9           2.4            3.3           1.0  Iris-versicolor

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df['Species']=l.fit_transform(df['Species'])

# %%
df.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 67             5.8           2.7            4.1           1.0        1
# 27             5.2           3.5            1.5           0.2        0
# 139            6.9           3.1            5.4           2.1        2
# 63             6.1           2.9            4.7           1.4        1
# 3              4.6           3.1            1.5           0.2        0

# %%
import seaborn as sn
sn.pairplot(df,hue='Species',palette="bright")

# %%
sn.heatmap(df.corr())
# Out:
# <Axes: >

# %%
x=df.drop('Species',axis=1)

# %%
y=df['Species']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
# Train Test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm     Species
# count     150.000000    150.000000     150.000000    150.000000  150.000000
# mean        5.843333      3.054000       3.758667      1.198667    1.000000
# std         0.828066      0.433594       1.764420      0.763161    0.819232
# min         4.300000      2.000000       1.000000      0.100000    0.000000
# 25%         5.100000      2.800000       1.600000      0.300000    0.000000
# 50%         5.800000      3.000000       4.350000      1.300000    1.000000
# 75%         6.400000      3.300000       5.100000      1.800000    2.000000
# max         7.900000      4.400000       6.900000      2.500000    2.000000

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
x_train=s.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.2657343 , -0.58155249,  0.65710697,  1.04500386],
#        [-0.74888757,  0.7654257 , -1.30620045, -1.27859296],
#        [ 1.0629372 ,  0.54092934,  1.10586296,  1.17409257],
#        [-0.86967589,  0.7654257 , -1.25010595, -1.27859296],
#        [ 0.70057224,  0.09193661,  0.99367396,  0.78682644],
#        [ 1.30451383,  0.09193661,  0.93757946,  1.17409257],
#        [-0.2657343 , -0.13255976,  0.43272898,  0.3995603 ],
#        [-0.62809925,  1.43891479, -1.25010595, -1.27859296],
#        [ 1.66687878,  1.21441843,  1.33024095,  1.69044742],
#        [-0.2657343 , -0.13255976,  0.20835099,  0.14138288],
#        [-0.2657343 , -0.80604885,  0.26444549,  0.14138288],
#        [-1.35282916,  0.31643297, -1.19401145, -1.27859296],
#        [ 0.70057224, -0.80604885,  0.88148497,  0.91591515],
#        [ 1.18372551, -0.13255976,  0.99367396,  1.17409257],
#        [ 0.57978393, -0.58155249,  0.76929597,  0.3995603 ],
#        [-0.38652262,  2.56139662, -1.30620045, -1.27859296],
#        [ 2.27082037, -1.03054522,  1.77899693,  1.43227   ],
#        [-0.99046421,  1.21441843, -1.30620045, -1.27859296],
#        [-0.99046421, -2.3775234 , -0.128216  , -0.24588326],
#        [ 0.33820729, -0.13255976,  0.65710697,  0.78682644],
#        [ 0.57978393, -1.25504158,  0.65710697,  0.3995603 ],
#        [-1.83598243, -0.13255976, -1.47448394, -1.40768167],
#        [ 0.33820729, -0.13255976,  0.48882348,  0.27047159],
#        [ 0.57978393,  0.54092934,  0.54491798,  0.52864901],
#        [ 0.70057224, -0.58155249,  1.04976846,  1.17409257],
#        [-0.2657343 , -1.25504158,  0.096162  , -0.11679455],
#        [-0.38652262, -1.47953794,  0.0400675 , -0.11679455],
#        [ 1.0629372 ,  0.09193661,  1.04976846,  1.56135871],
#        [-1.47361748,  0.31643297, -1.30620045, -1.27859296],
#        [-0.38652262, -1.03054522,  0.37663449,  0.01229416],
#        [-0.38652262, -1.25504158,  0.15225649,  0.14138288],
#        [-1.71519411, -0.13255976, -1.36229495, -1.27859296],
#        [ 1.0629372 , -0.13255976,  0.71320147,  0.65773772],
#        [-1.47361748,  0.09193661, -1.25010595, -1.27859296],
#        [-0.14494598, -1.25504158,  0.71320147,  1.04500386],
#        [-1.23204084, -0.13255976, -1.30620045, -1.14950425],
#        [ 1.30451383,  0.31643297,  1.10586296,  1.43227   ],
#        [ 0.57978393, -0.35705612,  1.04976846,  0.78682644],
#        [-0.99046421, -0.13255976, -1.19401145, -1.27859296],
#        [-0.02415766, -0.80604885,  0.76929597,  0.91591515],
#        [ 1.42530215,  0.31643297,  0.54491798,  0.27047159],
#        [-0.99046421, -1.70403431, -0.24040499, -0.24588326],
#        [-0.50731093,  1.43891479, -1.25010595, -1.27859296],
#        [ 0.09663065, -0.13255976,  0.26444549,  0.3995603 ],
#        [-1.35282916,  0.31643297, -1.36229495, -1.27859296],
#        [-0.50731093,  0.7654257 , -1.25010595, -1.02041554],
#        [ 1.0629372 , -0.13255976,  0.82539047,  1.43227   ],
#        [ 0.45899561, -0.35705612,  0.32053999,  0.14138288],
#        [-0.38652262, -1.47953794, -0.016027  , -0.24588326],
#        [ 0.33820729, -1.03054522,  1.04976846,  0.27047159],
#        [-0.99046421,  0.98992206, -1.19401145, -0.76223811],
#        [ 1.0629372 ,  0.54092934,  1.10586296,  1.69044742],
#        [-0.14494598,  1.66341116, -1.13791696, -1.14950425],
#        [ 0.33820729, -0.58155249,  0.15225649,  0.14138288],
#        [-1.59440579, -1.70403431, -1.36229495, -1.14950425],
#        [ 0.45899561, -0.58155249,  0.60101248,  0.78682644]])

# %%
x_test=s.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.82136056, -0.58155249,  0.48882348,  0.3995603 ],
#        [ 0.82136056, -0.13255976,  1.16195746,  1.30318129],
#        [-0.14494598,  3.01038934, -1.25010595, -1.02041554],
#        [-0.99046421,  0.98992206, -1.36229495, -1.14950425],
#        [ 0.21741897, -1.92853067,  0.15225649, -0.24588326],
#        [ 0.57978393,  0.54092934,  1.27414645,  1.69044742],
#        [-0.38652262, -1.70403431,  0.15225649,  0.14138288],
#        [-0.86967589, -1.25504158, -0.40868848, -0.11679455],
#        [ 0.57978393, -0.80604885,  0.65710697,  0.78682644],
#        [-0.14494598, -0.35705612,  0.26444549,  0.14138288],
#        [ 1.0629372 , -1.25504158,  1.16195746,  0.78682644],
#        [ 0.21741897,  0.7654257 ,  0.43272898,  0.52864901],
#        [-0.14494598, -0.58155249,  0.20835099,  0.14138288],
#        [ 1.7876671 , -0.35705612,  1.44242994,  0.78682644],
#        [-1.23204084,  0.09193661, -1.19401145, -1.27859296],
#        [ 0.94214888, -0.13255976,  0.37663449,  0.27047159],
#        [ 0.57978393,  0.7654257 ,  1.04976846,  1.56135871],
#        [ 0.70057224,  0.31643297,  0.43272898,  0.3995603 ],
#        [ 1.18372551, -0.58155249,  0.60101248,  0.27047159],
#        [-1.71519411, -0.35705612, -1.30620045, -1.27859296],
#        [ 0.82136056, -0.13255976,  0.82539047,  1.04500386],
#        [ 0.21741897, -0.13255976,  0.60101248,  0.78682644],
#        [-0.74888757, -0.80604885,  0.096162  ,  0.27047159],
#        [ 0.57978393, -1.25504158,  0.71320147,  0.91591515],
#        [ 1.66687878, -0.13255976,  1.16195746,  0.52864901],
#        [-0.99046421,  0.7654257 , -1.25010595, -1.27859296],
#        [-0.02415766, -1.03054522,  0.15225649,  0.01229416],
#        [ 1.90845542, -0.58155249,  1.33024095,  0.91591515],
#        [-1.23204084,  0.7654257 , -1.19401145, -1.27859296],
#        [ 1.66687878,  0.31643297,  1.27414645,  0.78682644],
#        [-1.23204084, -0.13255976, -1.30620045, -1.40768167],
#        [-0.86967589,  1.66341116, -1.25010595, -1.14950425],
#        [-1.11125252,  0.09193661, -1.25010595, -1.40768167],
#        [ 0.21741897, -0.35705612,  0.43272898,  0.3995603 ],
#        [ 1.30451383,  0.09193661,  0.76929597,  1.43227   ],
#        [ 0.94214888, -0.35705612,  0.48882348,  0.14138288],
#        [ 0.70057224, -0.35705612,  0.32053999,  0.14138288],
#        [-1.23204084,  0.7654257 , -1.02572796, -1.27859296],
#        [-0.86967589,  1.43891479, -1.25010595, -1.02041554],
#        [ 0.82136056, -0.13255976,  0.99367396,  0.78682644],
#        [-0.99046421,  0.54092934, -1.30620045, -1.27859296],
#        [-1.47361748,  0.7654257 , -1.30620045, -1.14950425],
#        [ 1.18372551,  0.31643297,  1.21805195,  1.43227   ],
#        [-0.86967589,  0.54092934, -1.13791696, -0.89132682],
#        [-0.02415766, -0.80604885,  0.096162  ,  0.01229416]])

# %%
from sklearn.linear_model import LogisticRegression
l=LogisticRegression()
l.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=l.predict(x_test)

# %%
y=y_test.to_numpy()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_score(y_pred,y)
# Out:
# 1.0

# %%
confusion_matrix(y,y_pred)
# Out:
# array([[14,  0,  0],
#        [ 0, 16,  0],
#        [ 0,  0, 15]])

# %%
import pickle
with open('model.pkl', 'wb') as f:
    pickle.dump(l, f)

# %%
with open('model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
loaded_model.predict(x_test)
# Out:
# array([1, 2, 0, 0, 1, 2, 1, 1, 2, 1, 2, 1, 1, 2, 0, 1, 2, 1, 1, 0, 2, 2,
#        1, 2, 2, 0, 1, 2, 0, 2, 0, 0, 0, 1, 2, 1, 1, 0, 0, 2, 0, 0, 2, 0,
#        1])
